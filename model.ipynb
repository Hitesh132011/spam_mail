# %%
import numpy as np
import pandas as pd

# Specify the correct encoding for the CSV file
df = pd.read_csv('spam1.csv', encoding='latin-1')
df.sample(5)
# Out:
#        v1                                                 v2 Unnamed: 2  \
# 2671  ham      That's cool, I'll come by like  &lt;#&gt; ish        NaN
# 2147  ham  Ok. Can be later showing around 8-8:30 if you ...        NaN
# 5017  ham  Babe ! What are you doing ? Where are you ? Wh...        NaN
# 2961  ham       \NONE!NOWHERE IKNO DOESDISCOUNT!SHITINNIT\""        NaN
# 3076  ham            There is no sense in my foot and penis.        NaN
#
#      Unnamed: 3 Unnamed: 4
# 2671        NaN        NaN
# 2147        NaN        NaN
# 5017        NaN        NaN
# 2961        NaN        NaN
# 3076        NaN        NaN

# %%
df.shape
# Out:
# (5572, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   v1          5572 non-null   object
#  1   v2          5572 non-null   object
#  2   Unnamed: 2  50 non-null     object
#  3   Unnamed: 3  12 non-null     object
#  4   Unnamed: 4  6 non-null      object
# dtypes: object(5)
# memory usage: 217.8+ KB

# %%
df.drop(columns=['Unnamed: 2','Unnamed: 3','Unnamed: 4'],inplace=True)
df.sample(5)
# Out:
#         v1                                                 v2
# 2351  spam  Download as many ringtones as u like no restri...
# 1391   ham                Haha just kidding, papa needs drugs
# 675    ham                 I dont knw pa, i just drink milk..
# 5120  spam       PRIVATE! Your 2003 Account Statement for 078
# 3944   ham  I will be gentle princess! We will make sweet ...

# %%
df.rename(columns={'v1':'target','v2':'text'},inplace=True)
df.sample(5)
# Out:
#      target                                               text
# 3440   spam  Get a FREE mobile video player FREE movie. To ...
# 3384    ham                                          Ok can...
# 4104    ham  Jus finish my lunch on my way home lor... I to...
# 1818    ham                       Am i that much dirty fellow?
# 651     ham  I'm gonna say no. Sorry. I would but as normal...

# %%
from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()

# %%
df['target']=encoder.fit_transform(df['target'])
df.head()
# Out:
#    target                                               text
# 0       0  Go until jurong point, crazy.. Available only ...
# 1       0                      Ok lar... Joking wif u oni...
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3       0  U dun say so early hor... U c already then say...
# 4       0  Nah I don't think he goes to usf, he lives aro...

# %%
df.isnull().sum()
# Out:
# target    0
# text      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 403

# %%
df=df.drop_duplicates(keep='first')
df.duplicated().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (5169, 2)

# %% [markdown]
# ##EDAM

# %%
df.head(5)
# Out:
#    target                                               text
# 0       0  Go until jurong point, crazy.. Available only ...
# 1       0                      Ok lar... Joking wif u oni...
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3       0  U dun say so early hor... U c already then say...
# 4       0  Nah I don't think he goes to usf, he lives aro...

# %%
df['target'].value_counts()
df.head()
# Out:
#    target                                               text
# 0       0  Go until jurong point, crazy.. Available only ...
# 1       0                      Ok lar... Joking wif u oni...
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3       0  U dun say so early hor... U c already then say...
# 4       0  Nah I don't think he goes to usf, he lives aro...

# %%
import matplotlib.pyplot as plt
plt.pie(df['target'].value_counts(),labels=['ham','spam'],autopct="%.2f");

# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\hites\sample_project_1\env\lib\site-packages (3.8.1)
# Requirement already satisfied: click in c:\users\hites\sample_project_1\env\lib\site-packages (from nltk) (8.1.3)
# Requirement already satisfied: joblib in c:\users\hites\sample_project_1\env\lib\site-packages (from nltk) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\hites\sample_project_1\env\lib\site-packages (from nltk) (2023.6.3)
# Requirement already satisfied: tqdm in c:\users\hites\sample_project_1\env\lib\site-packages (from nltk) (4.65.0)
# Requirement already satisfied: colorama in c:\users\hites\appdata\roaming\python\python311\site-packages (from click->nltk) (0.4.6)

# %%
import nltk
from nltk.corpus import state_union
from nltk.tokenize import PunktSentenceTokenizer

# %%
df['num_characters']=df['text'].apply(len)

# %%
df.head()
# Out:
#    target                                               text  num_characters
# 0       0  Go until jurong point, crazy.. Available only ...             111
# 1       0                      Ok lar... Joking wif u oni...              29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3       0  U dun say so early hor... U c already then say...              49
# 4       0  Nah I don't think he goes to usf, he lives aro...              61

# %%
import re

# Check if 'text' column exists in the DataFrame
if 'text' in df.columns:
    # Apply tokenization to the 'text' column using the 're' module
    df['num_words'] =df['text'].apply(lambda x: re.findall(r'\w+', str(x)))
else:
    print("Error: 'text' column not found in DataFrame")
    
df['num_words']=df['num_words'].apply(len)
df.head()
# Out:
#    target                                               text  num_characters  \
# 0       0  Go until jurong point, crazy.. Available only ...             111
# 1       0                      Ok lar... Joking wif u oni...              29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3       0  U dun say so early hor... U c already then say...              49
# 4       0  Nah I don't think he goes to usf, he lives aro...              61
#
#    num_words
# 0         20
# 1          6
# 2         33
# 3         11
# 4         14

# %%
df['num_sentences'] = df['text'].apply(lambda x: re.split(r'(?<=[.!?])\s+', str(x)))
df['num_sentences']=df['num_sentences'].apply(len)
df.head()
# Out:
#    target                                               text  num_characters  \
# 0       0  Go until jurong point, crazy.. Available only ...             111
# 1       0                      Ok lar... Joking wif u oni...              29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3       0  U dun say so early hor... U c already then say...              49
# 4       0  Nah I don't think he goes to usf, he lives aro...              61
#
#    num_words  num_sentences
# 0         20              3
# 1          6              2
# 2         33              2
# 3         11              2
# 4         14              1

# %%
df[['num_characters','num_words','num_sentences']].describe()
# Out:
#        num_characters    num_words  num_sentences
# count     5169.000000  5169.000000    5169.000000
# mean        78.977945    15.989940       2.096150
# std         58.236293    11.518372       1.524009
# min          2.000000     0.000000       1.000000
# 25%         36.000000     8.000000       1.000000
# 50%         60.000000    12.000000       2.000000
# 75%        117.000000    23.000000       3.000000
# max        910.000000   190.000000      39.000000

# %%
df[df['target']==0][['num_characters','num_words','num_sentences']].describe()
# Out:
#        num_characters    num_words  num_sentences
# count     4516.000000  4516.000000    4516.000000
# mean        70.459256    14.600974       1.957263
# std         56.358207    11.448193       1.465646
# min          2.000000     0.000000       1.000000
# 25%         34.000000     7.000000       1.000000
# 50%         52.000000    11.000000       2.000000
# 75%         90.000000    19.000000       2.000000
# max        910.000000   190.000000      39.000000

# %%
df[df['target']==1][['num_characters','num_words','num_sentences']].describe()
# Out:
#        num_characters   num_words  num_sentences
# count      653.000000  653.000000     653.000000
# mean       137.891271   25.595712       3.056662
# std         30.137753    6.185684       1.573800
# min         13.000000    2.000000       1.000000
# 25%        132.000000   24.000000       2.000000
# 50%        149.000000   27.000000       3.000000
# 75%        157.000000   29.000000       4.000000
# max        224.000000   40.000000       9.000000

# %%
# !pip install seaborn
import seaborn as sns
# Out:
# Requirement already satisfied: seaborn in c:\users\hites\sample_project_1\env\lib\site-packages (0.12.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in c:\users\hites\sample_project_1\env\lib\site-packages (from seaborn) (1.23.5)
# Requirement already satisfied: pandas>=0.25 in c:\users\hites\sample_project_1\env\lib\site-packages (from seaborn) (1.5.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in c:\users\hites\sample_project_1\env\lib\site-packages (from seaborn) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\hites\sample_project_1\env\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\hites\sample_project_1\env\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\hites\sample_project_1\env\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\hites\sample_project_1\env\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\hites\appdata\roaming\python\python311\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\hites\sample_project_1\env\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\hites\sample_project_1\env\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\hites\appdata\roaming\python\python311\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hites\sample_project_1\env\lib\site-packages (from pandas>=0.25->seaborn) (2022.7)
# Requirement already satisfied: six>=1.5 in c:\users\hites\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)

# %%
plt.figure(figsize=(12,8))
sns.histplot(df[df['target']==0]['num_characters'])
sns.histplot(df[df['target']==1]['num_characters'],color='red')
# Out:
# <Axes: xlabel='num_characters', ylabel='Count'>

# %%
plt.figure(figsize=(12,8))
sns.histplot(df[df['target']==0]['num_words'])
sns.histplot(df[df['target']==1]['num_words'],color='red')
# Out:
# <Axes: xlabel='num_words', ylabel='Count'>

# %%
plt.figure(figsize=(12,8))
sns.histplot(df[df['target']==0]['num_sentences'])
sns.histplot(df[df['target']==1]['num_sentences'],color='red')
# Out:
# <Axes: xlabel='num_sentences', ylabel='Count'>

# %%
sns.pairplot(df,hue='target')

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# C:\Users\hites\AppData\Local\Temp\ipykernel_11356\4277794465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True)
# <Axes: >

# %%
import re
from nltk.stem import PorterStemmer

def transform_text(text):
    stopwords = ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', 'her', 'hers', 'herself', 'it', 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', 'should', 'now']
    stemmer = PorterStemmer()
    text = text.lower()
    tokens = re.findall(r'\w+', text)
    filtered_tokens = [token for token in tokens if re.match(r'^\w+$', token)]
    filtered_tokens = [token for token in filtered_tokens if token not in stopwords and re.match(r'^\w+$', token)]
    stemmed_tokens = [stemmer.stem(token) for token in filtered_tokens]
    return " ".join(stemmed_tokens)

# %%
transform_text("I'm gonna be home soon and i don't want to talk about this stuff anymore tonight, k? I've cried enough today.")
# Out:
# 'm gonna home soon want talk stuff anymor tonight k ve cri enough today'

# %%
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()
ps.stem('loving')
# Out:
# 'love'

# %%
df['transformed_text'] = df['text'].apply(transform_text)
df.head()
# Out:
#    target                                               text  num_characters  \
# 0       0  Go until jurong point, crazy.. Available only ...             111
# 1       0                      Ok lar... Joking wif u oni...              29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3       0  U dun say so early hor... U c already then say...              49
# 4       0  Nah I don't think he goes to usf, he lives aro...              61
#
#    num_words  num_sentences                                   transformed_text
# 0         20              3  go jurong point crazi avail bugi n great world...
# 1          6              2                              ok lar joke wif u oni
# 2         33              2  free entri 2 wkli comp win fa cup final tkt 21...
# 3         11              2                u dun say earli hor u c alreadi say
# 4         14              1               nah think goe usf live around though

# %%
# !pip install wordcloud
from wordcloud import WordCloud
wc=WordCloud(width=500,height=500,min_font_size=10,background_color='white')
spam_wc=wc.generate(df[df['target']==1]['transformed_text'].str.cat(sep=" "))
# Out:
# Requirement already satisfied: wordcloud in c:\users\hites\sample_project_1\env\lib\site-packages (1.9.2)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\hites\sample_project_1\env\lib\site-packages (from wordcloud) (1.23.5)
# Requirement already satisfied: pillow in c:\users\hites\sample_project_1\env\lib\site-packages (from wordcloud) (9.4.0)
# Requirement already satisfied: matplotlib in c:\users\hites\sample_project_1\env\lib\site-packages (from wordcloud) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\hites\sample_project_1\env\lib\site-packages (from matplotlib->wordcloud) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\hites\sample_project_1\env\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\hites\sample_project_1\env\lib\site-packages (from matplotlib->wordcloud) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\hites\sample_project_1\env\lib\site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\hites\appdata\roaming\python\python311\site-packages (from matplotlib->wordcloud) (23.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\hites\sample_project_1\env\lib\site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\hites\appdata\roaming\python\python311\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\hites\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)

# %%
plt.figure(figsize=(15,6))
plt.imshow(spam_wc)

# %%
ham_wc=wc.generate(df[df['target']==0]['transformed_text'].str.cat(sep=" "))
plt.figure(figsize=(15,6))
plt.imshow(ham_wc)

# %%
df.head()
# Out:
#    target                                               text  num_characters  \
# 0       0  Go until jurong point, crazy.. Available only ...             111
# 1       0                      Ok lar... Joking wif u oni...              29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3       0  U dun say so early hor... U c already then say...              49
# 4       0  Nah I don't think he goes to usf, he lives aro...              61
#
#    num_words  num_sentences                                   transformed_text
# 0         20              3  go jurong point crazi avail bugi n great world...
# 1          6              2                              ok lar joke wif u oni
# 2         33              2  free entri 2 wkli comp win fa cup final tkt 21...
# 3         11              2                u dun say earli hor u c alreadi say
# 4         14              1               nah think goe usf live around though

# %%
spam_corpus=[]
for msg in df[df['target']==1]['transformed_text'].tolist():
    for words in msg.split():
        spam_corpus.append(words)
len(spam_corpus)
# Out:
# 12117

# %%
word_counts = Counter(spam_corpus).most_common(30)

# Convert the word counts to a DataFrame
word_counts_df = pd.DataFrame(word_counts, columns=['Word', 'Count'])

# Create the bar plot
sns.barplot(data=word_counts_df, x='Word', y='Count')
plt.xticks(rotation='vertical')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 word_counts = Counter(spam_corpus).most_common(30)
#       3 # Convert the word counts to a DataFrame
#       4 word_counts_df = pd.DataFrame(word_counts, columns=['Word', 'Count'])
#
# NameError: name 'Counter' is not defined

# %%
ham_corpus=[]
for msg in df[df['target']==0]['transformed_text'].tolist():
    for words in msg.split():
        ham_corpus.append(words)
len(ham_corpus)

# %%
word_counts = Counter(ham_corpus).most_common(30)

# Convert the word counts to a DataFrame
word_counts_df = pd.DataFrame(word_counts, columns=['Word', 'Count'])

# Create the bar plot
sns.barplot(data=word_counts_df, x='Word', y='Count')
plt.xticks(rotation='vertical')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 word_counts = Counter(ham_corpus).most_common(30)
#       3 # Convert the word counts to a DataFrame
#       4 word_counts_df = pd.DataFrame(word_counts, columns=['Word', 'Count'])
#
# NameError: name 'Counter' is not defined

# %%
df.head()
# Out:
#    target                                               text  num_characters  \
# 0       0  Go until jurong point, crazy.. Available only ...             111
# 1       0                      Ok lar... Joking wif u oni...              29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3       0  U dun say so early hor... U c already then say...              49
# 4       0  Nah I don't think he goes to usf, he lives aro...              61
#
#    num_words  num_sentences                                   transformed_text
# 0         20              3  go jurong point crazi avail bugi n great world...
# 1          6              2                              ok lar joke wif u oni
# 2         33              2  free entri 2 wkli comp win fa cup final tkt 21...
# 3         11              2                u dun say earli hor u c alreadi say
# 4         14              1               nah think goe usf live around though

# %%
from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer
cv=CountVectorizer()
tfidf=TfidfVectorizer(max_features=3000)
X=tfidf.fit_transform(df['transformed_text']).toarray()
X.shape
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
X=scaler.fit_transform(X)

# %%
y=df['target'].values
y
# Out:
# array([0, 0, 1, ..., 0, 0, 0])

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=.2,random_state=2)

# %%
from sklearn.naive_bayes import GaussianNB,MultinomialNB,BernoulliNB
from sklearn.metrics import accuracy_score,confusion_matrix,precision_score

# %%
gnb=GaussianNB()
mnb=MultinomialNB()
bnb=BernoulliNB()

# %%
gnb.fit(X_train,y_train)
y_pred1=gnb.predict(X_test)
print(accuracy_score(y_test,y_pred1))
print(confusion_matrix(y_test,y_pred1))
print(precision_score(y_test,y_pred1))
# Out:
# 0.8820116054158608
# [[785 111]
#  [ 11 127]]
# 0.5336134453781513

# %%
mnb.fit(X_train,y_train)
y_pred2=mnb.predict(X_test)
print(accuracy_score(y_test,y_pred2))
print(confusion_matrix(y_test,y_pred2))
print(precision_score(y_test,y_pred2))
# Out:
# 0.9835589941972921
# [[890   6]
#  [ 11 127]]
# 0.9548872180451128

# %%
bnb.fit(X_train,y_train)
y_pred3=bnb.predict(X_test)
print(accuracy_score(y_test,y_pred3))
print(confusion_matrix(y_test,y_pred3))
print(precision_score(y_test,y_pred3))
# Out:
# 0.988394584139265
# [[896   0]
#  [ 12 126]]
# 1.0

# %%
# !pip install xgboost
# Out:
# Requirement already satisfied: xgboost in c:\users\hites\sample_project_1\env\lib\site-packages (1.7.6)
# Requirement already satisfied: numpy in c:\users\hites\sample_project_1\env\lib\site-packages (from xgboost) (1.23.5)
# Requirement already satisfied: scipy in c:\users\hites\sample_project_1\env\lib\site-packages (from xgboost) (1.10.1)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.naive_bayes import MultinomialNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import GradientBoostingClassifier
from xgboost import XGBClassifier
svc = SVC(kernel='sigmoid', gamma=1.0)
knc = KNeighborsClassifier()
mnb = MultinomialNB()
dtc = DecisionTreeClassifier(max_depth=5)
lrc = LogisticRegression(solver='liblinear', penalty='l1')
rfc = RandomForestClassifier(n_estimators=50, random_state=2)
abc = AdaBoostClassifier(n_estimators=50, random_state=2)
bc = BaggingClassifier(n_estimators=50, random_state=2)
etc = ExtraTreesClassifier(n_estimators=50, random_state=2)
gbdt = GradientBoostingClassifier(n_estimators=50,random_state=2)
xgb = XGBClassifier(n_estimators=50,random_state=2)

# %%
clfs = {
    'SVC' : svc,
    'KN' : knc, 
    'NB': mnb, 
    'DT': dtc, 
    'LR': lrc, 
    'RF': rfc, 
    'AdaBoost': abc, 
    'BgC': bc, 
    'ETC': etc,
    'GBDT':gbdt,
    'xgb':xgb
}

# %%
def train_classifier(clf,X_train,y_train,X_test,y_test):
    clf.fit(X_train,y_train)
    y_pred = clf.predict(X_test)
    accuracy = accuracy_score(y_test,y_pred)
    precision = precision_score(y_test,y_pred)
    
    return accuracy,precision

# %%
train_classifier(svc,X_train,y_train,X_test,y_test)
accuracy_scores = []
precision_scores = []

for name,clf in clfs.items():
    
    current_accuracy,current_precision = train_classifier(clf, X_train,y_train,X_test,y_test)
    
    print("For ",name)
    print("Accuracy - ",current_accuracy)
    print("Precision - ",current_precision)
    
    accuracy_scores.append(current_accuracy)
    precision_scores.append(current_precision)
# Out:
# For  SVC
# Accuracy -  0.9777562862669246
# Precision -  0.967479674796748
# For  KN
# Accuracy -  0.90715667311412
# Precision -  1.0
# For  NB
# Accuracy -  0.9835589941972921
# Precision -  0.9548872180451128
# For  DT
# Accuracy -  0.9342359767891683
# Precision -  0.8240740740740741
# For  LR
# Accuracy -  0.9738878143133463
# Precision -  0.9743589743589743
# For  RF
# Accuracy -  0.9738878143133463
# Precision -  0.9826086956521739
# For  AdaBoost
# Accuracy -  0.9690522243713733
# Precision -  0.9568965517241379
# For  BgC
# Accuracy -  0.9555125725338491
# Precision -  0.8432835820895522
# For  ETC
# Accuracy -  0.9806576402321083
# Precision -  0.9758064516129032
# For  GBDT
# Accuracy -  0.9477756286266924
# Precision -  0.9375
# For  xgb
# Accuracy -  0.9700193423597679
# Precision -  0.9495798319327731

# %%
performance_df = pd.DataFrame({'Algorithm':clfs.keys(),'Accuracy':accuracy_scores,'Precision':precision_scores}).sort_values('Precision',ascending=False)

# %%
performance_df
# Out:
#    Algorithm  Accuracy  Precision
# 1         KN  0.907157   1.000000
# 5         RF  0.973888   0.982609
# 8        ETC  0.980658   0.975806
# 4         LR  0.973888   0.974359
# 0        SVC  0.977756   0.967480
# 6   AdaBoost  0.969052   0.956897
# 2         NB  0.983559   0.954887
# 10       xgb  0.970019   0.949580
# 9       GBDT  0.947776   0.937500
# 7        BgC  0.955513   0.843284
# 3         DT  0.934236   0.824074

# %%
performance_df1=pd.melt(performance_df,id_vars="Algorithm")
performance_df1
# Out:
#    Algorithm   variable     value
# 0         KN   Accuracy  0.907157
# 1         RF   Accuracy  0.973888
# 2        ETC   Accuracy  0.980658
# 3         LR   Accuracy  0.973888
# 4        SVC   Accuracy  0.977756
# 5   AdaBoost   Accuracy  0.969052
# 6         NB   Accuracy  0.983559
# 7        xgb   Accuracy  0.970019
# 8       GBDT   Accuracy  0.947776
# 9        BgC   Accuracy  0.955513
# 10        DT   Accuracy  0.934236
# 11        KN  Precision  1.000000
# 12        RF  Precision  0.982609
# 13       ETC  Precision  0.975806
# 14        LR  Precision  0.974359
# 15       SVC  Precision  0.967480
# 16  AdaBoost  Precision  0.956897
# 17        NB  Precision  0.954887
# 18       xgb  Precision  0.949580
# 19      GBDT  Precision  0.937500
# 20       BgC  Precision  0.843284
# 21        DT  Precision  0.824074

# %%
sns.catplot(x='Algorithm',y='value',hue='variable',data=performance_df1,kind='bar',height=5)
plt.ylim(0.5,1.0)
plt.xticks(rotation='vertical')
plt.show()

# %%
temp_df = pd.DataFrame({'Algorithm':clfs.keys(),'Accuracy_max_ft_3000':accuracy_scores,'Precision_max_ft_3000':precision_scores}).sort_values('Precision_max_ft_3000',ascending=False)

# %%
temp_df = pd.DataFrame({'Algorithm':clfs.keys(),'Accuracy_scaling':accuracy_scores,'Precision_scaling':precision_scores}).sort_values('Precision_scaling',ascending=False)

# %%
new_df = performance_df.merge(temp_df,on='Algorithm')

# %%
new_df_scaled = new_df.merge(temp_df,on='Algorithm')

# %%
new_df_scaled.merge(temp_df,on='Algorithm')
# Out:
#    Algorithm  Accuracy  Precision  Accuracy_scaling_x  Precision_scaling_x  \
# 0         KN  0.907157   1.000000            0.907157             1.000000
# 1         RF  0.973888   0.982609            0.973888             0.982609
# 2        ETC  0.980658   0.975806            0.980658             0.975806
# 3         LR  0.973888   0.974359            0.973888             0.974359
# 4        SVC  0.977756   0.967480            0.977756             0.967480
# 5   AdaBoost  0.969052   0.956897            0.969052             0.956897
# 6         NB  0.983559   0.954887            0.983559             0.954887
# 7        xgb  0.970019   0.949580            0.970019             0.949580
# 8       GBDT  0.947776   0.937500            0.947776             0.937500
# 9        BgC  0.955513   0.843284            0.955513             0.843284
# 10        DT  0.934236   0.824074            0.934236             0.824074
#
#     Accuracy_scaling_y  Precision_scaling_y  Accuracy_scaling  \
# 0             0.907157             1.000000          0.907157
# 1             0.973888             0.982609          0.973888
# 2             0.980658             0.975806          0.980658
# 3             0.973888             0.974359          0.973888
# 4             0.977756             0.967480          0.977756
# 5             0.969052             0.956897          0.969052
# 6             0.983559             0.954887          0.983559
# 7             0.970019             0.949580          0.970019
# 8             0.947776             0.937500          0.947776
# 9             0.955513             0.843284          0.955513
# 10            0.934236             0.824074          0.934236
#
#     Precision_scaling
# 0            1.000000
# 1            0.982609
# 2            0.975806
# 3            0.974359
# 4            0.967480
# 5            0.956897
# 6            0.954887
# 7            0.949580
# 8            0.937500
# 9            0.843284
# 10           0.824074

# %%
svc=SVC(kernel='sigmoid',gamma=1.0,probability=True)
mnb=MultinomialNB()
etc=ExtraTreesClassifier(n_estimators=50,random_state=2)
from sklearn.ensemble import VotingClassifier
voting = VotingClassifier(estimators=[('svm', svc), ('nb', mnb), ('et', etc)],voting='soft')
voting.fit(X_train,y_train)
# Out:
# VotingClassifier(estimators=[('svm',
#                               SVC(gamma=1.0, kernel='sigmoid',
#                                   probability=True)),
#                              ('nb', MultinomialNB()),
#                              ('et',
#                               ExtraTreesClassifier(n_estimators=50,
#                                                    random_state=2))],
#                  voting='soft')

# %%
y_pred = voting.predict(X_test)
print("Accuracy",accuracy_score(y_test,y_pred))
print("Precision",precision_score(y_test,y_pred))
# Out:
# Accuracy 0.9864603481624759
# Precision 0.984375

# %%
estimators=[('svm', svc), ('nb', mnb), ('et', etc)]
final_estimator=RandomForestClassifier()

# %%
from sklearn.ensemble import StackingClassifier
clf = StackingClassifier(estimators=estimators, final_estimator=final_estimator)
clf.fit(X_train,y_train)
y_pred = clf.predict(X_test)
print("Accuracy",accuracy_score(y_test,y_pred))
print("Precision",precision_score(y_test,y_pred))
# Out:
# Accuracy 0.988394584139265
# Precision 0.9772727272727273

# %%
import pickle
pickle.dump(tfidf,open('vectorizer.pkl','wb'))
pickle.dump(mnb,open('model.pkl','wb'))
